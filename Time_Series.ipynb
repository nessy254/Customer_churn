# %% [markdown]
# <a href="https://colab.research.google.com/github/nessy254/Customer_churn/blob/main/Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('craigslist_vehicles.csv',
                 delimiter=",",
                 engine="python",
                 error_bad_lines=False,
                 encoding='utf-8')
# Out:
# <ipython-input-40-1d204c8eb456>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('craigslist_vehicles.csv',
# Skipping line 40983: unexpected end of data

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40981 entries, 0 to 40980
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    40981 non-null  int64
#  1   id            40981 non-null  int64
#  2   url           40981 non-null  object
#  3   region        40981 non-null  object
#  4   region_url    40981 non-null  object
#  5   price         40981 non-null  int64
#  6   year          40881 non-null  float64
#  7   manufacturer  39351 non-null  object
#  8   model         40412 non-null  object
#  9   condition     22291 non-null  object
#  10  cylinders     23601 non-null  object
#  11  fuel          40829 non-null  object
#  12  odometer      40600 non-null  float64
#  13  title_status  40048 non-null  object
#  14  transmission  40760 non-null  object
#  15  VIN           27121 non-null  object
#  16  drive         28902 non-null  object
#  17  size          10228 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# id                  0
# url                 0
# region              0
# region_url          0
# price               0
# year              100
# manufacturer     1630
# model             569
# condition       18690
# cylinders       17380
# fuel              152
# odometer          381
# title_status      933
# transmission      221
# VIN             13860
# drive           12079
# size            30753
# type             8582
# paint_color     13324
# image_url          11
# description        11
# county          40981
# state               0
# lat               451
# long              451
# posting_date       11
# removal_date       11
# dtype: int64

# %%
#drop the county column, all the values are nan
new_df = df.drop('county', axis = 1)

# %%
new_df.head(19)
# Out:
#     Unnamed: 0          id                                                url  \
# 0       362773  7307679724  https://abilene.craigslist.org/ctd/d/abilene-2...
# 1       362712  7311833696  https://abilene.craigslist.org/ctd/d/abilene-2...
# 2       362722  7311441996  https://abilene.craigslist.org/ctd/d/abilene-2...
# 3       362771  7307680715  https://abilene.craigslist.org/ctd/d/abilene-2...
# 4       362710  7311834578  https://abilene.craigslist.org/ctd/d/abilene-2...
# 5       362772  7307680254  https://abilene.craigslist.org/ctd/d/abilene-2...
# 6       362711  7311834077  https://abilene.craigslist.org/ctd/d/abilene-2...
# 7       362723  7311441803  https://abilene.craigslist.org/ctd/d/abilene-2...
# 8       362763  7308988448  https://abilene.craigslist.org/ctd/d/abilene-2...
# 9       362752  7309998951  https://abilene.craigslist.org/ctd/d/abilene-2...
# 10      362804  7305927171  https://abilene.craigslist.org/ctd/d/abilene-2...
# ...
